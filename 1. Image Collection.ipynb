# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\brahm\desktop\tensorflow object detection\tfod\venv_tflatest\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\brahm\desktop\tensorflow object detection\tfod\venv_tflatest\lib\site-packages (from opencv-python) (1.24.4)

# %%
# Import opencv
import cv2 

# Import uuid
import uuid


# Import Operating System
import os

# Import time
import time

# %%
labels = ['thumbsup', 'thumbsdown', 'thankyou', 'livelong']
number_imgs = 5

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %%
import my_cv_lib.image_processing as ip
import numpy as np
os.environ["OPENCV_VIDEOIO_PRIORITY_MSMF"] = "0"

#Define labels and number of images per label
labels = ['thumbsup', 'thumbsdown', 'thankyou', 'livelong']
number_imgs = 10 #Exactly 10 images per sign

#Define the path to save images
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')
print("Saving images to:", IMAGES_PATH)

#Create folders for each label if they don't exist
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        os.makedirs(path)

#Optimize webcam settings (force max resolution & keep latest frame)
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)  
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)
cap.set(cv2.CAP_PROP_FPS, 30)  # Reduce FPS to prevent freezing
cap.set(cv2.CAP_PROP_BUFFERSIZE, 1)  # Keep only the latest frame

# Print actual resolution being used
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
print(f"Webcam resolution: {width}x{height}")

#  Start capturing images
for label in labels:
    print(f'Collecting images for {label}')
    time.sleep(10)  

    for imgnum in range(number_imgs):  # Capture exactly 5 images
        print(f'Collecting image {imgnum + 1} of {number_imgs}')

        # Ensure latest frame is captured
        cap.grab()  # Force OpenCV to grab the newest frame
        ret, frame = cap.read()

        if not ret or frame is None:
            print("Failed to capture image from webcam! Retrying...")
            continue  # Skip this iteration if frame capture fails
        else:
            print("Frame Captured!")

        # Resize image using your custom library (Now 720x720)
        resized = ip.resize_image(frame, 720, 720)

        # Convert to 8-bit before saving (prevents black images)
        resized = resized.astype(np.uint8)

        # Save processed image
        imgname = os.path.join(IMAGES_PATH, label, f"{label}.{uuid.uuid1()}.jpg")
        success = cv2.imwrite(imgname, resized)

        if success:
            print(f"Processed image saved: {imgname}")
        else:
            print("Failed to save image!")

        # Display processed image
        cv2.imshow('Processed Image', resized)

        time.sleep(2)  # Slight delay between captures for better variety

        # Break if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Saving images to: Tensorflow\workspace\images\collectedimages
# Webcam resolution: 1920x1080
# Collecting images for thumbsup
# Collecting image 1 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.c43c3126-f0c4-11ef-840b-c87f5470702e.jpg
# Collecting image 2 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.c5788046-f0c4-11ef-83cb-c87f5470702e.jpg
# Collecting image 3 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.c6ae531e-f0c4-11ef-8065-c87f5470702e.jpg
# Collecting image 4 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.c7e332db-f0c4-11ef-9332-c87f5470702e.jpg
# Collecting image 5 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.c91db83d-f0c4-11ef-a43f-c87f5470702e.jpg
# Collecting image 6 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.ca6ab85d-f0c4-11ef-ae46-c87f5470702e.jpg
# Collecting image 7 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.cba47ec2-f0c4-11ef-8e2a-c87f5470702e.jpg
# Collecting image 8 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.ccdceba7-f0c4-11ef-a28c-c87f5470702e.jpg
# Collecting image 9 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.ce131ba2-f0c4-11ef-8c99-c87f5470702e.jpg
# Collecting image 10 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.cf492c43-f0c4-11ef-b063-c87f5470702e.jpg
# Collecting images for thumbsdown
# Collecting image 1 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.d67819f8-f0c4-11ef-a5d5-c87f5470702e.jpg
# Collecting image 2 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.d7ad6604-f0c4-11ef-92ab-c87f5470702e.jpg
# Collecting image 3 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.d8e3954f-f0c4-11ef-a1f6-c87f5470702e.jpg
# Collecting image 4 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.da1eb435-f0c4-11ef-880e-c87f5470702e.jpg
# Collecting image 5 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.db55d3dc-f0c4-11ef-9a77-c87f5470702e.jpg
# Collecting image 6 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.dc923022-f0c4-11ef-82ff-c87f5470702e.jpg
# Collecting image 7 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.ddc9bfaf-f0c4-11ef-ab2c-c87f5470702e.jpg
# Collecting image 8 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.df007f02-f0c4-11ef-8d25-c87f5470702e.jpg
# Collecting image 9 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.e036b12c-f0c4-11ef-8c70-c87f5470702e.jpg
# Collecting image 10 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.e16d90db-f0c4-11ef-bcc9-c87f5470702e.jpg
# Collecting images for thankyou
# Collecting image 1 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thankyou\thankyou.e89d0abc-f0c4-11ef-aa95-c87f5470702e.jpg
# Collecting image 2 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thankyou\thankyou.e9d2c364-f0c4-11ef-800c-c87f5470702e.jpg
# Collecting image 3 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thankyou\thankyou.eb086aad-f0c4-11ef-8353-c87f5470702e.jpg
# Collecting image 4 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thankyou\thankyou.ec3fe782-f0c4-11ef-a123-c87f5470702e.jpg
# Collecting image 5 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thankyou\thankyou.ed756d0a-f0c4-11ef-bbf9-c87f5470702e.jpg
# Collecting image 6 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thankyou\thankyou.eeac6d85-f0c4-11ef-baf7-c87f5470702e.jpg
# Collecting image 7 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thankyou\thankyou.efe45d20-f0c4-11ef-a2ac-c87f5470702e.jpg
# Collecting image 8 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thankyou\thankyou.f11f60ba-f0c4-11ef-b930-c87f5470702e.jpg
# Collecting image 9 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thankyou\thankyou.f25c8684-f0c4-11ef-9fff-c87f5470702e.jpg
# Collecting image 10 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\thankyou\thankyou.f392a9fa-f0c4-11ef-aaa4-c87f5470702e.jpg
# Collecting images for livelong
# Collecting image 1 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\livelong\livelong.fabf898b-f0c4-11ef-bafd-c87f5470702e.jpg
# Collecting image 2 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\livelong\livelong.fbf52e95-f0c4-11ef-8dbe-c87f5470702e.jpg
# Collecting image 3 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\livelong\livelong.fd2c93f4-f0c4-11ef-bf3c-c87f5470702e.jpg
# Collecting image 4 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\livelong\livelong.fe633889-f0c4-11ef-b557-c87f5470702e.jpg
# Collecting image 5 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\livelong\livelong.ff99fbd7-f0c4-11ef-b0ed-c87f5470702e.jpg
# Collecting image 6 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\livelong\livelong.00d1cbfc-f0c5-11ef-a830-c87f5470702e.jpg
# Collecting image 7 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\livelong\livelong.020cd441-f0c5-11ef-8ebb-c87f5470702e.jpg
# Collecting image 8 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\livelong\livelong.034798b8-f0c5-11ef-91f7-c87f5470702e.jpg
# Collecting image 9 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\livelong\livelong.047d3f76-f0c5-11ef-a7a4-c87f5470702e.jpg
# Collecting image 10 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\livelong\livelong.05b64706-f0c5-11ef-96e6-c87f5470702e.jpg
# Collecting images for peace
# Collecting image 1 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\peace\peace.0ce396b7-f0c5-11ef-9bb7-c87f5470702e.jpg
# Collecting image 2 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\peace\peace.0e184e68-f0c5-11ef-ab13-c87f5470702e.jpg
# Collecting image 3 of 10
# Frame Captured!
# Processed image saved: Tensorflow\workspace\images\collectedimages\peace\peace.0f4bb1af-f0c5-11ef-a9f6-c87f5470702e.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 67
#      64 # Display processed image
#      65 cv2.imshow('Processed Image', resized)
# ---> 67 time.sleep(2)  # Slight delay between captures for better variety
#      69 # Break if 'q' is pressed
#      70 if cv2.waitKey(1) & 0xFF == ord('q'):
#
# KeyboardInterrupt:

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Collecting pyqt5
#   Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: lxml in c:\users\brahm\desktop\tensorflow object detection\tfod\venv_tflatest\lib\site-packages (5.3.1)
# Collecting PyQt5-sip<13,>=12.15 (from pyqt5)
#   Downloading PyQt5_sip-12.17.0-cp39-cp39-win_amd64.whl.metadata (492 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from pyqt5)
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    --------- ------------------------------ 1.6/6.9 MB 8.4 MB/s eta 0:00:01
#    ------------------------------ --------- 5.2/6.9 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 12.8 MB/s eta 0:00:00
# Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#    ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#    ------ --------------------------------- 7.6/50.1 MB 39.3 MB/s eta 0:00:02
#    -------------- ------------------------- 18.6/50.1 MB 45.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 36.4/50.1 MB 57.9 MB/s eta 0:00:01
#    ---------------------------------------  50.1/50.1 MB 65.1 MB/s eta 0:00:01
#    ---------------------------------------  50.1/50.1 MB 65.1 MB/s eta 0:00:01
#    ---------------------------------------  50.1/50.1 MB 65.1 MB/s eta 0:00:01
#    ---------------------------------------  50.1/50.1 MB 65.1 MB/s eta 0:00:01
#    ---------------------------------------  50.1/50.1 MB 65.1 MB/s eta 0:00:01
#    ---------------------------------------  50.1/50.1 MB 65.1 MB/s eta 0:00:01
#    ---------------------------------------  50.1/50.1 MB 65.1 MB/s eta 0:00:01
#    ---------------------------------------- 50.1/50.1 MB 22.0 MB/s eta 0:00:00
# Downloading PyQt5_sip-12.17.0-cp39-cp39-win_amd64.whl (59 kB)
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, pyqt5
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.17.0 pyqt5-5.15.11

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}
# Out:
# Cloning into 'Tensorflow\labelimg'...

# %%
if os.name == 'posix':
    # !cd {LABELIMG_PATH} && make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
